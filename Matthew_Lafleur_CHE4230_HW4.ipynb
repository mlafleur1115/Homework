# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Users/12254/OneDrive/Documents/Semester 7/CHE 4230/Homework/meter_Hw4/data/Meter_A.txt', sep='\t', header=None).dropna()
data.head()
# Out:
#          0         1         2         3          4          5         6   \
# 0  0.841499  1.009367  0.993816  8.469805  10.278727  10.037759  8.501365
# 1  0.842250  1.006584  0.996605  7.531891   9.139924   8.951618  7.612213
# 2  0.840723  1.011647  0.998152  6.641699   7.975464   7.857692  6.593117
# 3  0.841119  1.017807  0.996812  5.687524   6.824334   6.689885  5.615428
# 4  0.840358  1.016534  0.996221  5.660385   6.829560   6.675628  5.623977
#
#          7          8          9   ...         27         28         29  \
# 0  8.581726  10.247763  10.058822  ...  32.451173  34.568685  33.082683
# 1  7.623325   9.106345   8.945142  ...  32.428385  34.441732  33.081055
# 2  6.681572   7.964596   7.814698  ...  32.428385  34.275715  33.113605
# 3  5.763315   6.801051   6.686639  ...  32.485350  34.080403  33.170573
# 4  5.736818   6.813453   6.672377  ...  32.503255  34.122720  33.164062
#
#           30         31         32         33         34         35  36
# ...

# %%
data = data.to_numpy()
data
# Out:
# array([[ 0.84149871,  1.00936653,  0.99381601, ..., 35.174155  ,
#         32.72949   ,  1.        ],
#        [ 0.84225022,  1.00658369,  0.99660521, ..., 34.847005  ,
#         32.73112167,  1.        ],
#        [ 0.84072314,  1.01164657,  0.99815174, ..., 34.68912833,
#         32.77181   ,  1.        ],
#        ...,
#        [ 0.79347112,  1.00955964,  1.00111012, ..., 33.82487   ,
#         33.02083167,  2.        ],
#        [ 0.79672987,  1.01057037,  0.99902897, ..., 33.81673167,
#         33.01106667,  2.        ],
#        [ 0.79019427,  1.00419541,  0.99553749, ..., 33.66862167,
#         33.11848833,  2.        ]])

# %%
def load_data(path):
    data = pd.read_csv(path, sep='\t', header=None).dropna()
    print(data.head())
    data = data.to_numpy()
    return data

# %%
data = load_data('C:/Users/12254/OneDrive/Documents/Semester 7/CHE 4230/Homework/meter_Hw4/data/Meter_A.txt')
# Out:
#          0         1         2         3          4          5         6   \
# 0  0.841499  1.009367  0.993816  8.469805  10.278727  10.037759  8.501365
# 1  0.842250  1.006584  0.996605  7.531891   9.139924   8.951618  7.612213
# 2  0.840723  1.011647  0.998152  6.641699   7.975464   7.857692  6.593117
# 3  0.841119  1.017807  0.996812  5.687524   6.824334   6.689885  5.615428
# 4  0.840358  1.016534  0.996221  5.660385   6.829560   6.675628  5.623977
#
#          7          8          9   ...         27         28         29  \
# 0  8.581726  10.247763  10.058822  ...  32.451173  34.568685  33.082683
# 1  7.623325   9.106345   8.945142  ...  32.428385  34.441732  33.081055
# 2  6.681572   7.964596   7.814698  ...  32.428385  34.275715  33.113605
# 3  5.763315   6.801051   6.686639  ...  32.485350  34.080403  33.170573
# 4  5.736818   6.813453   6.672377  ...  32.503255  34.122720  33.164062
#
#           30         31         32         33         34         35  36
# ...

# %%
import sys
import os

os.chdir("C:/Users/12254/OneDrive/Documents/Semester 7/CHE 4230/Homework/meter_Hw4")
os.getcwd()
# Out:
# 'C:\\Users\\12254\\OneDrive\\Documents\\Semester 7\\CHE 4230\\Homework\\meter_Hw4'

# %%
from src.data_preprocess import DataPreprocessing

# %%
preprocessor = DataPreprocessing()

preprocessor.load_data("data/Meter_A.txt")
# Out:
#          0         1         2         3          4          5         6   \
# 0  0.841499  1.009367  0.993816  8.469805  10.278727  10.037759  8.501365
# 1  0.842250  1.006584  0.996605  7.531891   9.139924   8.951618  7.612213
# 2  0.840723  1.011647  0.998152  6.641699   7.975464   7.857692  6.593117
# 3  0.841119  1.017807  0.996812  5.687524   6.824334   6.689885  5.615428
# 4  0.840358  1.016534  0.996221  5.660385   6.829560   6.675628  5.623977
#
#          7          8          9   ...         27         28         29  \
# 0  8.581726  10.247763  10.058822  ...  32.451173  34.568685  33.082683
# 1  7.623325   9.106345   8.945142  ...  32.428385  34.441732  33.081055
# 2  6.681572   7.964596   7.814698  ...  32.428385  34.275715  33.113605
# 3  5.763315   6.801051   6.686639  ...  32.485350  34.080403  33.170573
# 4  5.736818   6.813453   6.672377  ...  32.503255  34.122720  33.164062
#
#           30         31         32         33         34         35  36
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
train_validation, test = train_test_split(data, test_size = 0.2, random_state=12)

train, validation = train_test_split(train_validation, test_size = 0.2, random_state=99)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler().fit(train[:, :-1])

train_scaled = scaler.transform(train[:, :-1])

# %%
# X_train = train[:, :-1]
Y_train = train[:, -1]

set(Y_train)
# Out:
# {np.float64(1.0), np.float64(2.0)}

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_model = DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
dt_model.fit(X = train_scaled, y = train[:, -1])
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
X_validation = scaler.transform(validation[:, :-1])
y_predicted = dt_model.predict(X_validation)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(validation[:, -1], y_predicted)
# Out:
# 0.9285714285714286

# %%
from src.model_builder import ModelBuilder

# %%
model_builder = ModelBuilder()

dt_model = model_builder.dt(X_train=train[:, :-1], X_test=validation[:, :-1], y_train=train[:, -1], y_test = validation[:, -1])

model_builder.accuracy
# Out:
# 0.9285714285714286

# %% [markdown]
# Results:
#
# By having smaller hidden layer size, the model doesn't learn patterns as effectively
#
# by having smaller learning rate initilizaiton, the model will run very slowly with smaller step sizes or could overshoot with too high of values
#
# by having too low max iterations, then the model could stop too early or waste time for too much noise.
